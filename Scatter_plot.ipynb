# %%
#importing bokeh and pandas
import pandas
from bokeh.plotting import figure
from bokeh.io import output_file, show
from bokeh.sampledata.iris import flowers

# %%
#Define the oputput file
output_file("Scatter_Iris.html")

# %%
#Create a figure object
f = figure()

# %%
flowers
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ## How to change the width and hight | Background Color | Transparency

# %%
#stylize the plot area
f.plot_width = 1100
f.plot_height = 650

# %% [markdown]
# ## Background Color and Transparency

# %%
f.background_fill_color ='orange'
f.background_fill_alpha = 0.5

# %% [markdown]
# ## Border Color

# %%
f.border_fill_color ='grey'

# %% [markdown]
# ## Add and Stylize the Title

# %%
#Title Text
f.title.text = 'Iris Morphology'
#Title Color
f.title.text_color = 'red'
#Title Size
f.title.text_font_size = "44px"
#Title Font
f.title.text_font ="times"
#Title Alignment
f.title.align ="center"

# %%
#Adding Glyph
f.circle(x=flowers["petal_length"],y=flowers["petal_width"])
# Out:
# bokeh.models.renderers.GlyphRenderer(
#     id='fac66f84-db92-4bd4-b65b-31aa44d9e358',
#     data_source=bokeh.models.sources.ColumnDataSource(
#         id='cb17f86d-10aa-4f21-86e8-47805a72a7bb',
#         callback=None,
#         data={'y': {'__ndarray__': '...',
#           'shape': (150,),
#           'dtype': 'float64'},
#          'x': {'__ndarray__': '...',
#           'shape': (150,),
#           'dtype': 'float64'}},
#         js_event_callbacks={},
#         js_property_callbacks={},
#         name=None,
#         selected=bokeh.models.selections.Selection(
#             id='d249b3b9-4b1f-47b5-8277-a5aeebcd26d4',
#             indices=[],
#             js_event_callbacks={},
#             js_property_callbacks={},
#             line_indices=[],
#             multiline_indices={},
#             name=None,
#             subscribed_events=[],
#             tags=[]),
#         selection_policy=bokeh.models.selections.UnionRenderers(
# ...

# %%
show(f)

# %%
# Use these attributes
dir(f)
# Out:
# ['__cached_all__overridden_defaults__',
#  '__cached_all__properties__',
#  '__cached_all__properties_with_refs__',
#  '__class__',
#  '__container_props__',
#  '__dataspecs__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__overridden_defaults__',
#  '__properties__',
#  '__properties_with_refs__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__subtype__',
#  '__view_model__',
#  '__weakref__',
#  '_attach_document',
#  '_axis',
#  '_callbacks',
#  '_check_compatible_scale_and_ranges',
#  '_check_missing_renderers',
#  '_check_required_range',
#  '_check_required_scale',
#  '_clear_extensions',
#  '_clone',
#  '_detach_document',
#  '_document',
#  '_event_callbacks',
#  '_grid',
# ...

# %% [markdown]
# ## Modify Axes Styling

# %%
#Style the axex
f.axis.minor_tick_line_color = "blue"
#Major Label Orientation
f.yaxis.major_label_orientation = "vertical"
#To hide the lable
f.xaxis.visible =True #False
#To remove minor ticks
f.axis.minor_tick_line_color = None

# %% [markdown]
# ## Add Axis Lable

# %%
f.xaxis.axis_label = "Petal Length"
f.yaxis.axis_label = "Petal Width"
f.axis.axis_label_text_color = "red"
f.axis.major_label_text_color = "blue"

# %% [markdown]
# # Axes Geometry (Range of the Axes)

# %%
from bokeh.models import Range1d
f.x_range = Range1d(start = 0,end =10)
f.y_range = Range1d(start = 0,end =5)
#Add Bound
#f.xaxis.bounds = (2,5)
#Control Ticker Number
f.xaxis[0].ticker.desired_num_ticks =5

# %%
show(f)

# %% [markdown]
# # Style the Grid

# %%
f.xgrid.grid_line_color = "blue"
f.ygrid.grid_line_color = "red"

# %%
#Add dashlines
f.grid.grid_line_dash = [5,3]

# %% [markdown]
# # Style the Tools/ Add or remove the tools

# %%
from bokeh.models import PanTool,ResetTool, HoverTool
f.tools=[PanTool(),ResetTool()]

# %%
# Check all the tools
import bokeh.models
dir(bokeh.models.tools)
# Out:
# ['Action',
#  'Anchor',
#  'Auto',
#  'Bool',
#  'BoxAnnotation',
#  'BoxEditTool',
#  'BoxSelectTool',
#  'BoxZoomTool',
#  'Callback',
#  'Color',
#  'CompilationError',
#  'CrosshairTool',
#  'CustomJSHover',
#  'DEFAULT_BOX_OVERLAY',
#  'DEFAULT_HELP_TIP',
#  'DEFAULT_HELP_URL',
#  'DEFAULT_POLY_OVERLAY',
#  'DEFAULT_RANGE_OVERLAY',
#  'Date',
#  'Datetime',
#  'Dict',
#  'Dimension',
#  'Dimensions',
#  'Drag',
#  'EditTool',
#  'Either',
#  'Enum',
#  'Float',
#  'FunctionType',
#  'Gesture',
#  'GlyphRenderer',
#  'HelpTool',
#  'HoverTool',
#  'INCOMPATIBLE_BOX_EDIT_RENDERER',
#  'INCOMPATIBLE_POINT_DRAW_RENDERER',
#  'INCOMPATIBLE_POLY_DRAW_RENDERER',
#  'INCOMPATIBLE_POLY_EDIT_RENDERER',
#  'INCOMPATIBLE_POLY_EDIT_VERTEX_RENDERER',
#  'Inspection',
#  'Instance',
#  'Int',
#  'LassoSelectTool',
#  'LayoutDOM',
#  'List',
#  'Location',
#  'Model',
#  'MultiLine',
#  'NO_RANGE_TOOL_RANGES',
#  'PanTool',
#  'Patches',
#  'Percent',
#  'PointDrawTool',
#  'PolyAnnotation',
# ...

# %% [markdown]
# # Remove Bokeh Logo

# %%
f.toolbar.logo =None

# %% [markdown]
# # Style the Glyphs

# %%
f.circle(x=flowers["petal_length"],y=flowers["petal_width"],size =flowers["sepal_width"]*4,fill_alpha = 0.2,color =flowers['color'],legend ='flowers')
# Out:
# bokeh.models.renderers.GlyphRenderer(
#     id='b3c3264b-02b6-4c97-b23d-ad98b36a8fdd',
#     data_source=bokeh.models.sources.ColumnDataSource(
#         id='91345c2f-eefd-4523-a647-ac394c098859',
#         callback=None,
#         data={'fill_color': ['red',
#           'red',
#           'red',
#           'red',
#           'red',
#           'red',
#           'red',
#           'red',
#           'red',
#           'red',
#           'red',
#           'red',
#           'red',
#           'red',
#           'red',
#           'red',
#           'red',
#           'red',
#           'red',
#           'red',
#           'red',
#           'red',
#           'red',
#           'red',
#           'red',
#           'red',
#           'red',
#           'red',
#           'red',
#           'red',
#           'red',
#           'red',
#           'red',
#           'red',
#           'red',
#           'red',
#           'red',
#           'red',
#           'red',
# ...

# %%
colormap ={'setosa' :'red','versicolor':'green','virginica':'blue'}
flowers['color']=[colormap[x] for x in flowers['species']]

# %%
show(f)

# %%
flowers['species']
# Out:
# 0         setosa
# 1         setosa
# 2         setosa
# 3         setosa
# 4         setosa
#          ...
# 145    virginica
# 146    virginica
# 147    virginica
# 148    virginica
# 149    virginica
# Name: species, Length: 150, dtype: object

# %% [markdown]
# # Add Tooltips

# %%
hover =HoverTool(tooltips =[("species","@species"),("Sepal Width","@sepal_width")])
